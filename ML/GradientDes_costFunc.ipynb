# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
def gradient_descent(x,y):
    m_curr=b_curr=0
    iterations=100
    n=len(x)
    learning_rate=0.0002
    for i in range(iterations):
        y_predicted=m_curr*x +b_curr
        md=-(2/n)*sum(x*(y-y_predicted))
        bd=-(2/n)*sum(y-y_predicted)
        m_curr=m_curr - learning_rate*md
        b_curr=b_curr - learning_rate*bd
        print("m {} , b {},iterations {}".format(m_curr,b_curr,i))
df=pd.read_csv("test_scores.csv")
x=df["math"]
y=df["cs"]


gradient_descent(x,y)
# Out:
# m 1.9783600000000003 , b 0.027960000000000002,iterations 0
# m 0.2097504127999994 , b 0.0030470367999999894,iterations 1
# m 1.7908456142986247 , b 0.02540128695526401,iterations 2
# m 0.3773816366753042 , b 0.005499731626422651,iterations 3
# m 1.6409848166378902 , b 0.023373894401807954,iterations 4
# m 0.5113514173939648 , b 0.007477430543482801,iterations 5
# m 1.5212165764726313 , b 0.02177112969849867,iterations 6
# m 0.6184191426785128 , b 0.009075514323270561,iterations 7
# m 1.4254981563597633 , b 0.020507724625171392,iterations 8
# m 0.7039868810749307 , b 0.010370210797388445,iterations 9
# m 1.3490002310389357 , b 0.01951553325074734,iterations 10
# m 0.7723719384951468 , b 0.011422440864086676,iterations 11
# m 1.2878632281408484 , b 0.01874009369115072,iterations 12
# m 0.8270246840299103 , b 0.01228089219775079,iterations 13
# m 1.2390025969113483 , b 0.01813788028359249,iterations 14
# m 0.8707026352388416 , b 0.012984475742007826,iterations 15
# m 1.1999531799587448 , b 0.017674107538129175,iterations 16
# m 0.9056095862354469 , b 0.013564288926616262,iterations 17
# m 1.1687448359398855 , b 0.017320975066834474,iterations 18
# m 0.9335067981503324 , b 0.014045184660493999,iterations 19
# m 1.1438030378387345 , b 0.01705626494005292,iterations 20
# m 0.9558018619881086 , b 0.014447025263025912,iterations 21
# m 1.1238694316123983 , b 0.01686222070059844,iterations 22
# m 0.9736197173740408 , b 0.014785684599634918,iterations 23
# m 1.107938347062055 , b 0.016724651477560696,iterations 24
# m 0.9878594103778673 , b 0.015073848983471564,iterations 25
# m 1.0952060576414995 , b 0.01663221599858156,iterations 26
# m 0.9992394540800739 , b 0.015321657252001259,iterations 27
# m 1.0850302291522724 , b 0.016575850376080885,iterations 28
# m 1.0083340805074805 , b 0.015537212312981732,iterations 29
# m 1.0768975113455126 , b 0.01654831079689666,iterations 30
# m 1.015602212997157 , b 0.015726989969425807,iterations 31
# m 1.0703976372937576 , b 0.016543808042154006,iterations 32
# m 1.021410620763412 , b 0.015896165650447942,iterations 33
# m 1.065202723739635 , b 0.016557715397389396,iterations 34
# m 1.026052423910844 , b 0.016048875532907392,iterations 35
# m 1.0610507280390307 , b 0.016586335215796482,iterations 36
# m 1.0297618825473562 , b 0.016188425228507265,iterations 37
# m 1.0577322270335767 , b 0.016626712356750502,iterations 38
# m 1.0327262161686235 , b 0.01631745656547063,iterations 39
# m 1.0550798507922887 , b 0.01667648508681882,iterations 40
# m 1.035095049650491 , b 0.01643808087961414,iterations 41
# m 1.052959838111218 , b 0.016733765920601176,iterations 42
# m 1.036987962438417 , b 0.01655198553990119,iterations 43
# m 1.0512652877114044 , b 0.016797046389330727,iterations 44
# m 1.0385005218215662 , b 0.016660519083126272,iterations 45
# m 1.0499107646303472 , b 0.016865120932420773,iterations 46
# m 1.0397091046950075 , b 0.016764759253124928,iterations 47
# m 1.0488279896772978 , b 0.016937026071973078,iterations 48
# m 1.0406747510877237 , b 0.016865567377366893,iterations 49
# m 1.047962394467687 , b 0.01701199180135197,iterations 50
# m 1.0414462438827428 , b 0.016963631824454834,iterations 51
# m 1.0472703682240316 , b 0.017089402735178165,iterations 52
# m 1.0420625701139212 , b 0.01705950273513797,iterations 53
# m 1.046717057433117 , b 0.01716876706059994,iterations 54
# m 1.0425548880219075 , b 0.017153619779162813,iterations 55
# m 1.0462746073431242 , b 0.017249691723305777,iterations 56
# m 1.0429480991153375 , b 0.01724633433840818,iterations 57
# m 1.0459207565770121 , b 0.017331862596310997,iterations 58
# m 1.0432621045542085 , b 0.01733792723553471,iterations 59
# m 1.0456377139546258 , b 0.017415028630952043,iterations 60
# m 1.0435128092451273 , b 0.017428622902632064,iterations 61
# m 1.0454112608545958 , b 0.017498989190441207,iterations 62
# m 1.0437129243091645 , b 0.01751860070473023,iterations 63
# m 1.0452300338265001 , b 0.017583583926907464,iterations 64
# m 1.0438726084101126 , b 0.017608003989492617,iterations 65
# m 1.0450849512581242 , b 0.01766868469117861,iterations 66
# m 1.043999980300792 , b 0.017696947319685064,iterations 67
# m 1.0449687551708302 , b 0.01775418906712003,iterations 68
# m 1.0441015284474728 , b 0.0177855222533286,iterations 69
# m 1.0448756450247292 , b 0.017840015204310795,iterations 70
# m 1.0441824383996428 , b 0.017873801963168307,iterations 71
# m 1.0448009850576234 , b 0.017926097688344588,iterations 72
# m 1.0442468544222752 , b 0.017961844928529553,iterations 73
# m 1.0447410703917646 , b 0.018012384240394946,iterations 74
# m 1.0442980885910158 , b 0.01804969788583084,iterations 75
# m 1.044692940107559 , b 0.018098833079524566,iterations 76
# m 1.0443387879000003 , b 0.01813739818661878,iterations 77
# m 1.044654227853013 , b 0.01818541081465612,iterations 78
# m 1.04437106781358 , b 0.018224975682097747,iterations 79
# m 1.044623042451559 , b 0.01827209075984605,iterations 80
# m 1.0443966190001837 , b 0.01831245422923645,iterations 81
# m 1.0445978724844307 , b 0.01835885158785985,iterations 82
# m 1.044416792633485 , b 0.018399852894440717,iterations 83
# m 1.044577510033378 , b 0.01844567625411622,iterations 84
# m 1.0444326685646634 , b 0.01848718691552271,iterations 85
# m 1.044560989736234 , b 0.018532551136708694,iterations 86
# m 1.0444451098053282 , b 0.018574468470501836,iterations 87
# m 1.044547540080427 , b 0.018619465349115263,iterations 88
# m 1.044454806070002 , b 0.018661707292026607,iterations 89
# m 1.0445365444770032 , b 0.018706410190919343,iterations 90
# m 1.0444623085750488 , b 0.018748911158417453,iterations 91
# m 1.0445275101511835 , b 0.018793378708828783,iterations 92
# m 1.0444680578498025 , b 0.018836086286105627,iterations 93
# m 1.0445200432798518 , b 0.018880365345844464,iterations 94
# m 1.0444724059630832 , b 0.018923237643268483,iterations 95
# m 1.0445138291215608 , b 0.018967365660877592,iterations 96
# m 1.0444756342865145 , b 0.019010369200485135,iterations 97
# m 1.0445086161365338 , b 0.019054376104669275,iterations 98
# m 1.0444779676908766 , b 0.019097484131059224,iterations 99

# %%
from sklearn import linear_model
new_df=df.drop(['name','cs'],axis='columns')
cs=df['math']
reg=linear_model.LinearRegression()
reg.fit(new_df,cs)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1.])

# %%
print(f"Coefficient: {reg.coef_[0]:.10f}")
# Out:
# Coefficient: 1.0000000000

# %%
reg.intercept_
# Out:
# np.float64(0.0)

# %%
print("Intercept: {:.10f}".format(reg.intercept_))
# Out:
# Intercept: 0.0000000000
