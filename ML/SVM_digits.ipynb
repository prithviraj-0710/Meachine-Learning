# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_digits

# %%
digits=load_digits()
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
df=pd.DataFrame(digits.data,columns=digits.feature_names)
df['target']=digits.target
dfi=df.drop(['target'],axis='columns')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dfi,df.target,test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.predict(X_test)
# Out:
# array([7, 4, 4, 5, 7, 8, 4, 9, 0, 1, 1, 1, 9, 9, 8, 0, 9, 9, 6, 7, 2, 8,
#        1, 4, 8, 2, 2, 9, 5, 7, 3, 4, 1, 3, 4, 0, 0, 2, 5, 8, 6, 9, 9, 1,
#        1, 0, 0, 1, 1, 2, 8, 8, 4, 5, 9, 7, 0, 3, 1, 9, 5, 9, 6, 9, 0, 5,
#        5, 0, 6, 6, 8, 2, 9, 5, 1, 8, 2, 4, 6, 1, 7, 5, 9, 1, 0, 2, 3, 4,
#        4, 1, 7, 4, 4, 5, 0, 8, 7, 7, 0, 0, 1, 3, 0, 8, 9, 3, 0, 7, 2, 5,
#        6, 3, 3, 5, 9, 0, 9, 6, 8, 2, 2, 7, 5, 2, 4, 1, 5, 8, 0, 1, 8, 2,
#        6, 5, 3, 2, 6, 4, 2, 9, 4, 3, 0, 4, 2, 4, 4, 3, 9, 8, 9, 6, 7, 9,
#        1, 1, 5, 4, 8, 9, 3, 7, 8, 8, 5, 5, 1, 1, 3, 7, 3, 9, 6, 3, 2, 9,
#        0, 4, 3, 4, 0, 5, 0, 0, 2, 9, 7, 9, 9, 5, 0, 9, 5, 3, 4, 9, 1, 5,
#        0, 0, 4, 3, 8, 2, 3, 0, 2, 9, 5, 6, 6, 7, 2, 8, 2, 3, 4, 5, 1, 3,
#        5, 9, 1, 2, 3, 6, 4, 7, 5, 7, 6, 1, 3, 6, 3, 2, 2, 2, 3, 6, 9, 7,
#        0, 4, 1, 9, 3, 0, 3, 1, 6, 9, 9, 2, 3, 8, 0, 7, 2, 8, 9, 8, 6, 6,
#        3, 9, 3, 9, 4, 2, 6, 2, 8, 0, 2, 3, 8, 8, 0, 5, 4, 0, 6, 9, 2, 5,
#        2, 6, 5, 6, 2, 2, 0, 5, 3, 8, 7, 9, 1, 2, 4, 3, 1, 4, 7, 2, 0, 7,
#        4, 8, 2, 6, 2, 6, 3, 4, 3, 3, 5, 0, 8, 1, 8, 0, 1, 5, 2, 0, 7, 5,
#        8, 4, 6, 0, 0, 9, 1, 7, 8, 2, 1, 8, 4, 5, 3, 4, 3, 8, 3, 5, 5, 9,
#        3, 4, 0, 6, 1, 9, 6, 0])

# %%
y_test
# Out:
# 494     7
# 650     4
# 1515    4
# 1259    5
# 1748    7
#        ..
# 1503    6
# 866     1
# 233     9
# 392     6
# 382     0
# Name: target, Length: 360, dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.9861111111111112
